# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatikah002/MachineLearning/blob/main/TG2_2341720003_Fatikah%20Salsabilla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1b359e91-c661-4116-b5e4-28488e065d15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b359e91-c661-4116-b5e4-28488e065d15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("wbc.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print("\n1. Pemisahan Variabel:")

# Tampilkan nama kolom
print("Kolom dalam dataset:", df.columns)

# Hapus kolom yang tidak digunakan (contoh: 'id')
df = df.drop(columns=["id"])

print("\nSetelah 'id' dihapus:")
print(df.columns)
# Out:
# 1. Pemisahan Variabel:
# Kolom dalam dataset: Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')
#
# Setelah 'id' dihapus:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
# ...

# %%
print("\n2. Encoding Kolom Diagnosis:")
le = LabelEncoder()
df_cleaned['diagnosis_encoded'] = le.fit_transform(df_cleaned['diagnosis'])

# Menampilkan hasil encoding
print("Hasil encoding:")
print(f"M (Malignant/Ganas) -> {le.transform(['M'])[0]}")
print(f"B (Benign/Jinak) -> {le.transform(['B'])[0]}")

# Membuat salinan kolom diagnosis sebelum menghapusnya (opsional)
diagnosis_original = df_cleaned['diagnosis'].copy()
# Out:
# 2. Encoding Kolom Diagnosis:
# Hasil encoding:
# M (Malignant/Ganas) -> 1
# B (Benign/Jinak) -> 0

# %%
# Ambil semua kolom numerik (selain diagnosis)
num_cols = df.drop(columns=["diagnosis"]).columns

# Standardisasi
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# Cek hasil 5 baris pertama
df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M     1.097064     -2.073335        1.269934   0.984375
# 1         M     1.829821     -0.353632        1.685955   1.908708
# 2         M     1.579888      0.456187        1.566503   1.558884
# 3         M    -0.768909      0.253732       -0.592687  -0.764464
# 4         M     1.750297     -1.151816        1.776573   1.826229
#
# ...
